# %%
# Load the magic
# %reload_ext datalintermagics

# %%
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
iris = datasets.load_iris()
X = np.array(iris.data)
#X[:,1]=np.nan
#print(X)

# %%
# Add data variable to linter with line magic
# %add_linter_data --tracked-variable X --data-header 'False' --data-delim ','
# Out:
# >>DEBUG: Added 'X' as linter data.

# %%
# %%lint --ip 0.0.0.0 --port 10000 --show-stats True --show-na False --show-passing False
# # This simply lints the data ;)
# Out:
# Response: 200, OK
# Linter output
# -------------
# • info         	(enum_detector)     	column: x2           just a few distinct values in 'column: x2', it could be an enum
# • experimental 	(many_missing_values)	column: x2           found many missing values in 'column: x2'
# 2 issues found from 15 linters applied (6 OK, 9 N/A) .

# %%
plt.scatter(X[:,1], X[:,2])
